# %%
#P58 - Transformação da base flags

import pandas as pd

#---------------------------------------------------------------------
#1-Importa a base de dados
#---------------------------------------------------------------------
flags = pd.read_csv('/workspaces/Pandas_python_livro_casa_do_codigo/main_project/flags.csv')

#---------------------------------------------------------------------
#2-Conversão dos atributos do Grupo 2
#   De: Categóricos não binários
#   Para: Categóricos binários
#---------------------------------------------------------------------
for c in flags.columns:
    if c in ['landmass','zone',
             'language','religion','mainhue',
             'topleft','botright']:
        dummies = pd.get_dummies(flags[c], prefix=c)
        flags = flags.join(dummies)


#---------------------------------------------------------------------
#3-Normalização dos atributos dos Grupo 3 e 4
#   De: Numéricos contínuos e discretos
#   Para: Numéricos com valores na faixa entre 0 e 1
#---------------------------------------------------------------------
for c in flags.columns:
    if c in ['area','population',
             'bars','stripes','colours',
             'circles','crosses','saltires',
             'quarters','sunstars']:

        c_max = max(flags[c])
        c_min = min(flags[c])
        flags[c] = (flags[c] - c_min) / (c_max - c_min)


#---------------------------------------------------------------------
#4-Exclusão dos atributos indesejados
#---------------------------------------------------------------------
flags = flags.drop(columns=['name', 'landmass',
                            'zone', 'language',
                            'religion', 'mainhue',
                            'topleft', 'botright',
                           ])


#---------------------------------------------------------------------
#5-Imprime a configuração final de flags
#---------------------------------------------------------------------
#Imprime as primeiras linhas
print('Head():'); print(flags.head())
print('-----------------------------------------')

#Imprime as últimas linhas
print('Tail():'); print(flags.tail())
print('-----------------------------------------')


#---------------------------------------------------------------------
#6-Salva o dataset alterado para um arquivo
#---------------------------------------------------------------------
flags.to_csv('/workspaces/Pandas_python_livro_casa_do_codigo/main_project/flags_transf.csv', sep=";", index=False)
# Out:
# Head():
#        area  population  bars   stripes   colours  red  green  blue  gold  \
# 0  0.028926    0.015873   0.0  0.214286  0.571429    1      1     0     1
# 1  0.001295    0.002976   0.0  0.000000  0.285714    1      0     0     1
# 2  0.106598    0.019841   0.4  0.000000  0.285714    1      1     0     0
# 3  0.000000    0.000000   0.0  0.000000  0.571429    1      0     1     1
# 4  0.000000    0.000000   0.6  0.000000  0.285714    1      0     1     1
#
#    white  ...  topleft_red  topleft_white  botright_black  botright_blue  \
# 0      1  ...        False          False           False          False
# 1      0  ...         True          False           False          False
# 2      1  ...        False          False           False          False
# 3      1  ...        False          False           False          False
# 4      0  ...        False          False           False          False
#
#    botright_brown  botright_gold  botright_green  botright_orange  \
# 0           False          False            True            False
# 1           False          False           False            False
# 2           False          False           False            False
# 3           False          False           False            False
# 4           False          False           False            False
#
#    botright_red  botright_white
# 0         False           False
# 1          True           False
# 2         False            True
# 3          True           False
# 4          True           False
#
# [5 rows x 73 columns]
# -----------------------------------------
# Tail():
#          area  population  bars   stripes   colours  red  green  blue  gold  \
# 189  0.000134    0.000000   0.0  0.000000  0.285714    1      0     1     0
# 190  0.011428    0.021825   0.0  0.214286  0.428571    1      0     1     1
# 191  0.040398    0.027778   0.0  0.000000  0.428571    1      1     0     1
# 192  0.033613    0.005952   0.6  0.000000  0.428571    1      1     0     0
# 193  0.017454    0.007937   0.0  0.500000  0.571429    1      1     0     1
#
#      white  ...  topleft_red  topleft_white  botright_black  botright_blue  \
# 189      1  ...        False          False           False          False
# 190      1  ...        False          False           False          False
# 191      0  ...        False          False           False          False
# 192      0  ...        False          False           False          False
# 193      1  ...        False          False           False          False
#
#      botright_brown  botright_gold  botright_green  botright_orange  \
# 189           False          False           False            False
# 190           False          False           False            False
# 191           False          False            True            False
# 192            True          False           False            False
# 193           False          False            True            False
#
#      botright_red  botright_white
# 189          True           False
# 190          True           False
# 191         False           False
# 192         False           False
# 193         False           False
#
# [5 rows x 73 columns]
# -----------------------------------------

# %% [markdown]
# # Implementação do modelo

# %%
#Parte 1 importação das bibliotes
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# %%
#Parte 2 carrega a base de dados treinamentos (feita no cap 6, transformando as colunas)
flags = pd.read_csv('/workspaces/Pandas_python_livro_casa_do_codigo/main_project/flags_transf.csv',sep= ';')
print(flags.columns)
# Out:
# Index(['area', 'population', 'bars', 'stripes', 'colours', 'red', 'green',
#        'blue', 'gold', 'white', 'black', 'orange', 'circles', 'crosses',
#        'saltires', 'quarters', 'sunstars', 'crescent', 'triangle', 'icon',
#        'animate', 'text', 'landmass_1', 'landmass_2', 'landmass_3',
#        'landmass_4', 'landmass_5', 'landmass_6', 'zone_1', 'zone_2', 'zone_3',
#        'zone_4', 'language_1', 'language_2', 'language_3', 'language_4',
#        'language_5', 'language_6', 'language_7', 'language_8', 'language_9',
#        'language_10', 'religion_0', 'religion_1', 'religion_2', 'religion_3',
#        'religion_4', 'religion_5', 'religion_6', 'religion_7', 'mainhue_black',
#        'mainhue_blue', 'mainhue_brown', 'mainhue_gold', 'mainhue_green',
#        'mainhue_orange', 'mainhue_red', 'mainhue_white', 'topleft_black',
#        'topleft_blue', 'topleft_gold', 'topleft_green', 'topleft_orange',
#        'topleft_red', 'topleft_white', 'botright_black', 'botright_blue',
#        'botright_brown', 'botright_gold', 'botright_green', 'botright_orange',
#        'botright_red', 'botright_white'],
#       dtype='object')

# %%
#Parte 3 configura os parâmetros e variáveis auxiliares
# valor de k a ser usado no k-nn (qtd de vizinhos considerados na classificação)
k = 3

#nomes das labels (rótulos de classe)
labels = ['red','green','blue','gold','white','black','orange']

# numero de labels = 7
n_labels = len(labels)

# numero de registros da base de treinamento = 194
n_registros = flags.shape[0]

# %%
#Parte 4 cria um classificador com o algoritmo k-NN 
# e faz a estimativa do desempenho usando o método LOO(Leave-One-Out)

#4.1 faz um loop que percorre cada rótulo

for i in range(0,n_labels):
    print('-----------------------------------------')
    print("PROCESSANDO O RÓTULO ", labels[i])

    #-----------------------------------------------------------
    # 4.1.1 instancia uma matriz de confusão para o rótulo j
    #-----------------------------------------------------------
    mc = pd.DataFrame({'predito_nao':[0,0],
                       'predito_sim':[0,0]},
                       index = ['real_nao','real_sim'])
    #-----------------------------------------------------------
    # 4.1.2 divide a base de treinamento verticalmente
    #       em duas partes: X (atributos preditivos) e
    #                      Y (atributo classe)
    #-----------------------------------------------------------
    X = flags.drop(columns=labels)
    Y = flags[labels[i]]


    #4.2 loop que realiza o LOO para os rótulos em no loop i

    for j in range(0,n_registros):
        
        #-----------------------------------------------------------
        # 4.2.1 Separa os dados que serão utilizados para treinar o modelo
        #-----------------------------------------------------------
        X_treino = X.drop([j])
        Y_treino = Y.drop([j])

        #-------------------------------------------
        # 4.2.2 Separa o objeto de teste
        #-------------------------------------------
        X_teste = X.iloc[[j],:]
        Y_teste = Y.iloc[j]
        #-----------------------------------------------------------
        # 4.2.3 Treinamento do modelo k-NN com os dados
        #       de treino
        #-----------------------------------------------------------
        modelo = KNeighborsClassifier(n_neighbors=k)
        modelo.fit(X_treino,Y_treino)
        
        #-----------------------------------------------------------
        # 4.2.4 Teste do modelo k-NN com o objeto de teste
        #-----------------------------------------------------------
        pred = modelo.predict(X_teste)

        #-----------------------------------------------------------
        # 4.2.5 Atualiza a celula adequada da matriz de confusão em função do resultado do teste
        #-----------------------------------------------------------
        if (Y_teste == 0):
            if (pred == 0): mc.iloc[0,0]+=1
            if (pred == 1): mc.iloc[0,1]+=1
        else:
            if (pred == 0): mc.iloc[1,0]+=1
            if (pred == 1): mc.iloc[1,1]+=1

    #-----------------------------------------------------------
    # 4.3 - Fim do LOO para o rótulo i:
    #       imprime a sua matriz de confusão e acurácia
    #-----------------------------------------------------------
    print(mc)
    acuracia = (mc.iloc[0,0] + mc.iloc[1,1]) / n_registros
    print('Acurácia = ',round(acuracia,2))
# Out:
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
#           predito_nao  predito_sim
# real_nao           20           21
# real_sim           22          131
# Acurácia =  0.78
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
#           predito_nao  predito_sim
# real_nao           88           15
# real_sim           17           74
# Acurácia =  0.84
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
#           predito_nao  predito_sim
# real_nao           64           31
# real_sim           28           71
# Acurácia =  0.7
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
#           predito_nao  predito_sim
# real_nao           81           22
# real_sim           37           54
# Acurácia =  0.7
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
#           predito_nao  predito_sim
# real_nao           18           30
# real_sim           24          122
# Acurácia =  0.72
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
#           predito_nao  predito_sim
# real_nao          125           17
# real_sim           28           24
# Acurácia =  0.77
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
#           predito_nao  predito_sim
# real_nao          163            5
# real_sim           20            6
# Acurácia =  0.87

# %% [markdown]
# # Testando diferentes k para ver o desempenho do modelo
# ## Vou usar a Medição de Acurácia identificar qual a melhor média de Acurácia

# %%
# Lista para armazenar resultados
resultados = []

# Loop para diferentes valores de k
for k in range(3, 21):
    print("\n========================")
    print(f"Testando k = {k}")
    print("========================")
    
    for i in range(0, n_labels):
        print('-----------------------------------------')
        print("PROCESSANDO O RÓTULO ", labels[i])

        mc = pd.DataFrame({'predito_nao':[0,0],
                           'predito_sim':[0,0]},
                           index=['real_nao','real_sim'])

        X = flags.drop(columns=labels)
        Y = flags[labels[i]]

        for j in range(0, n_registros):
            X_treino = X.drop([j])
            Y_treino = Y.drop([j])
            X_teste = X.iloc[[j], :]
            Y_teste = Y.iloc[j]

            modelo = KNeighborsClassifier(n_neighbors=k)
            modelo.fit(X_treino, Y_treino)
            pred = modelo.predict(X_teste)

            if (Y_teste == 0):
                if (pred == 0): mc.iloc[0,0]+=1
                else: mc.iloc[0,1]+=1
            else:
                if (pred == 0): mc.iloc[1,0]+=1
                else: mc.iloc[1,1]+=1

        acuracia = (mc.iloc[0,0] + mc.iloc[1,1]) / n_registros
        print('Acurácia = ', round(acuracia, 2))

        # Salva resultado
        resultados.append({"k": k, "label": labels[i], "acuracia": acuracia})

# ----- Resumo final -----
df_resultados = pd.DataFrame(resultados)
print("\nResumo final:")
print(df_resultados)

# Média por k
media_por_k = df_resultados.groupby("k")["acuracia"].mean().reset_index()
print("\nMédia geral das acurácias por k:")
print(media_por_k)
# Out:
# ========================
# Testando k = 3
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.78
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.84
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.7
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.7
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.72
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.77
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.87
#
# ========================
# Testando k = 4
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.79
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.81
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.71
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.68
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.68
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.75
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.86
#
# ========================
# Testando k = 5
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.82
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.83
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.69
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.68
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.74
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.74
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.87
#
# ========================
# Testando k = 6
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.8
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.81
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.71
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.63
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.73
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.77
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.86
#
# ========================
# Testando k = 7
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.81
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.82
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.72
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.67
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.76
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.75
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.87
#
# ========================
# Testando k = 8
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.83
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.82
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.72
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.64
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.75
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.77
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.86
#
# ========================
# Testando k = 9
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.83
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.82
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.73
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.67
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.75
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.74
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.87
#
# ========================
# Testando k = 10
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.84
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.83
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.74
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.62
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.75
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.74
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.86
#
# ========================
# Testando k = 11
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.84
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.83
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.74
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.65
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.74
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.73
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.87
#
# ========================
# Testando k = 12
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.82
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.82
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.75
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.65
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.75
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.72
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.87
#
# ========================
# Testando k = 13
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.81
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.81
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.76
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.65
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.76
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.74
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.87
#
# ========================
# Testando k = 14
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.83
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.84
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.77
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.65
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.76
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.74
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.87
#
# ========================
# Testando k = 15
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.82
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.83
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.76
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.65
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.75
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.75
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.87
#
# ========================
# Testando k = 16
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.82
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.82
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.77
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.65
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.77
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.75
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.87
#
# ========================
# Testando k = 17
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.82
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.82
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.77
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.64
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.76
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.75
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.87
#
# ========================
# Testando k = 18
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.84
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.79
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.77
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.63
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.75
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.74
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.87
#
# ========================
# Testando k = 19
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.83
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.82
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.78
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.64
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.75
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.74
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.86
#
# ========================
# Testando k = 20
# ========================
# -----------------------------------------
# PROCESSANDO O RÓTULO  red
# Acurácia =  0.83
# -----------------------------------------
# PROCESSANDO O RÓTULO  green
# Acurácia =  0.79
# -----------------------------------------
# PROCESSANDO O RÓTULO  blue
# Acurácia =  0.78
# -----------------------------------------
# PROCESSANDO O RÓTULO  gold
# Acurácia =  0.62
# -----------------------------------------
# PROCESSANDO O RÓTULO  white
# Acurácia =  0.77
# -----------------------------------------
# PROCESSANDO O RÓTULO  black
# Acurácia =  0.74
# -----------------------------------------
# PROCESSANDO O RÓTULO  orange
# Acurácia =  0.87
#
# Resumo final:
#       k   label  acuracia
# 0     3     red  0.778351
# 1     3   green  0.835052
# 2     3    blue  0.695876
# 3     3    gold  0.695876
# 4     3   white  0.721649
# ..   ..     ...       ...
# 121  20    blue  0.783505
# 122  20    gold  0.623711
# 123  20   white  0.768041
# 124  20   black  0.742268
# 125  20  orange  0.865979
#
# [126 rows x 3 columns]
#
# Média geral das acurácias por k:
#      k  acuracia
# 0    3  0.766568
# 1    4  0.753314
# 2    5  0.765096
# 3    6  0.758468
# 4    7  0.771723
# 5    8  0.770987
# 6    9  0.773932
# 7   10  0.768041
# 8   11  0.771723
# 9   12  0.768041
# 10  13  0.772459
# 11  14  0.779087
# 12  15  0.776878
# 13  16  0.778351
# 14  17  0.776141
# 15  18  0.768778
# 16  19  0.775405
# 17  20  0.772459

# %% [markdown]
# # Implementação do modelo e testes
# ### Média geral das acurácias por k
#
# | k   | Acurácia Média |
# |-----|----------------|
# | 3   | 0.7665 |
# | 4   | 0.7533 |
# | 5   | 0.7651 |
# | 6   | 0.7585 |
# | 7   | 0.7717 |
# | 8   | 0.7710 |
# | 9   | 0.7739 |
# | 10  | 0.7680 |
# | 11  | 0.7717 |
# | 12  | 0.7680 |
# | 13  | 0.7725 |
# | **14**  | **0.7791** |
# | 15  | 0.7769 |
# | 16  | 0.7784 |
# | 17  | 0.7761 |
# | 18  | 0.7688 |
# | 19  | 0.7754 |
# | 20  | 0.7725 |
#
# **Melhor resultado:** k = **14** com acurácia média de **0.7791**.

# %%
# Melhor k encontrado
k_otimo = 14

impacto_total = []  # Para guardar impacto de todas as variáveis em todos os labels

# Loop por cada label
for i in range(0, n_labels):
    print(f"\n======================")
    print(f"Analisando variáveis para o rótulo: {labels[i]}")
    print(f"======================")

    # Variáveis preditoras e target
    X_base = flags.drop(columns=labels)
    Y = flags[labels[i]]
    variaveis = X_base.columns

    #1. Acurácia base com todas as variáveis
    mc = pd.DataFrame({'predito_nao':[0,0],
                       'predito_sim':[0,0]},
                       index=['real_nao','real_sim'])

    for j in range(0, n_registros):
        X_treino = X_base.drop([j])
        Y_treino = Y.drop([j])
        X_teste = X_base.iloc[[j], :]
        Y_teste = Y.iloc[j]

        modelo = KNeighborsClassifier(n_neighbors=k_otimo)
        modelo.fit(X_treino, Y_treino)
        pred = modelo.predict(X_teste)

        if Y_teste == 0:
            if pred == 0: mc.iloc[0,0]+=1
            else: mc.iloc[0,1]+=1
        else:
            if pred == 0: mc.iloc[1,0]+=1
            else: mc.iloc[1,1]+=1

    acuracia_base = (mc.iloc[0,0] + mc.iloc[1,1]) / n_registros
    print(f"Acurácia base: {round(acuracia_base, 2)}")

    #2. Testa removendo cada variável
    impacto_label = []
    for var in variaveis:
        mc_var = pd.DataFrame({'predito_nao':[0,0],
                               'predito_sim':[0,0]},
                               index=['real_nao','real_sim'])
        
        X_var = X_base.drop(columns=[var])

        for j in range(0, n_registros):
            X_treino = X_var.drop([j])
            Y_treino = Y.drop([j])
            X_teste = X_var.iloc[[j], :]
            Y_teste = Y.iloc[j]

            modelo = KNeighborsClassifier(n_neighbors=k_otimo)
            modelo.fit(X_treino, Y_treino)
            pred = modelo.predict(X_teste)

            if Y_teste == 0:
                if pred == 0: mc_var.iloc[0,0]+=1
                else: mc_var.iloc[0,1]+=1
            else:
                if pred == 0: mc_var.iloc[1,0]+=1
                else: mc_var.iloc[1,1]+=1

        acuracia_var = (mc_var.iloc[0,0] + mc_var.iloc[1,1]) / n_registros
        perda = acuracia_base - acuracia_var
        impacto_label.append({"label": labels[i], "variavel": var, "impacto": perda})
        impacto_total.append({"label": labels[i], "variavel": var, "impacto": perda})

    # Ranking por label
    df_rank_label = pd.DataFrame(impacto_label).sort_values(by="impacto", ascending=False)
    print("\nRanking de variáveis por impacto neste label:")
    print(df_rank_label)

#Ranking geral
df_rank_geral = pd.DataFrame(impacto_total).groupby("variavel")["impacto"].mean().reset_index()
df_rank_geral = df_rank_geral.sort_values(by="impacto", ascending=False)

print("\n======================")
print("Ranking geral de variáveis por impacto médio:")
print("======================")
print(df_rank_geral)
# Out:
# ======================
# Analisando variáveis para o rótulo: red
# ======================
# Acurácia base: 0.8299
#
# Ranking de variáveis por impacto neste label:
#    label       variavel   impacto
# 59   red  botright_blue  0.046392
# 64   red   botright_red  0.041237
# 52   red   topleft_blue  0.030928
# 11   red       triangle  0.020619
# 56   red    topleft_red  0.020619
# ..   ...            ...       ...
# 30   red     language_6 -0.005155
# 16   red     landmass_2 -0.010309
# 20   red     landmass_6 -0.010309
# 40   red     religion_5 -0.010309
# 17   red     landmass_3 -0.015464
#
# [66 rows x 3 columns]
#
# ======================
# Analisando variáveis para o rótulo: green
# ======================
# Acurácia base: 0.8351
#
# Ranking de variáveis por impacto neste label:
#     label        variavel   impacto
# 11  green        triangle  0.025773
# 4   green         colours  0.025773
# 62  green  botright_green  0.025773
# 34  green     language_10  0.025773
# 12  green            icon  0.025773
# ..    ...             ...       ...
# 24  green          zone_4 -0.005155
# 19  green      landmass_5 -0.005155
# 6   green         crosses -0.005155
# 49  green     mainhue_red -0.005155
# 46  green    mainhue_gold -0.005155
#
# [66 rows x 3 columns]
#
# ======================
# Analisando variáveis para o rótulo: blue
# ======================
# Acurácia base: 0.768
#
# Ranking de variáveis por impacto neste label:
#    label       variavel   impacto
# 52  blue   topleft_blue  0.046392
# 51  blue  topleft_black  0.025773
# 30  blue     language_6  0.020619
# 46  blue   mainhue_gold  0.020619
# 17  blue     landmass_3  0.015464
# ..   ...            ...       ...
# 18  blue     landmass_4 -0.015464
# 40  blue     religion_5 -0.015464
# 16  blue     landmass_2 -0.020619
# 59  blue  botright_blue -0.020619
# 44  blue   mainhue_blue -0.025773
#
# [66 rows x 3 columns]
#
# ======================
# Analisando variáveis para o rótulo: gold
# ======================
# Acurácia base: 0.6495
#
# Ranking de variáveis por impacto neste label:
#    label       variavel   impacto
# 59  gold  botright_blue  0.020619
# 4   gold        colours  0.020619
# 37  gold     religion_2  0.015464
# 50  gold  mainhue_white  0.015464
# 34  gold    language_10  0.010309
# ..   ...            ...       ...
# 41  gold     religion_6 -0.010309
# 64  gold   botright_red -0.015464
# 54  gold  topleft_green -0.015464
# 52  gold   topleft_blue -0.020619
# 24  gold         zone_4 -0.025773
#
# [66 rows x 3 columns]
#
# ======================
# Analisando variáveis para o rótulo: white
# ======================
# Acurácia base: 0.7629
#
# Ranking de variáveis por impacto neste label:
#     label      variavel   impacto
# 38  white    religion_3  0.020619
# 37  white    religion_2  0.015464
# 52  white  topleft_blue  0.010309
# 56  white   topleft_red  0.010309
# 10  white      crescent  0.010309
# ..    ...           ...       ...
# 15  white    landmass_1 -0.010309
# 4   white       colours -0.015464
# 11  white      triangle -0.020619
# 12  white          icon -0.020619
# 40  white    religion_5 -0.025773
#
# [66 rows x 3 columns]
#
# ======================
# Analisando variáveis para o rótulo: black
# ======================
# Acurácia base: 0.7423
#
# Ranking de variáveis por impacto neste label:
#     label        variavel   impacto
# 54  black   topleft_green  0.020619
# 44  black    mainhue_blue  0.015464
# 57  black   topleft_white  0.015464
# 56  black     topleft_red  0.015464
# 49  black     mainhue_red  0.015464
# ..    ...             ...       ...
# 22  black          zone_2 -0.005155
# 21  black          zone_1 -0.005155
# 43  black   mainhue_black -0.020619
# 51  black   topleft_black -0.020619
# 62  black  botright_green -0.030928
#
# [66 rows x 3 columns]
#
# ======================
# Analisando variáveis para o rótulo: orange
# ======================
# Acurácia base: 0.866
#
# Ranking de variáveis por impacto neste label:
#      label         variavel   impacto
# 56  orange      topleft_red  0.005155
# 20  orange       landmass_6  0.005155
# 64  orange     botright_red  0.005155
# 57  orange    topleft_white  0.005155
# 1   orange       population  0.000000
# ..     ...              ...       ...
# 59  orange    botright_blue  0.000000
# 61  orange    botright_gold  0.000000
# 62  orange   botright_green  0.000000
# 63  orange  botright_orange  0.000000
# 65  orange   botright_white  0.000000
#
# [66 rows x 3 columns]
#
# ======================
# Ranking geral de variáveis por impacto médio:
# ======================
#          variavel   impacto
# 55   topleft_blue  0.011782
# 59    topleft_red  0.010309
# 4   botright_blue  0.008100
# 12        colours  0.008100
# 60  topleft_white  0.007364
# ..            ...       ...
# 14        crosses -0.002209
# 17     landmass_2 -0.002946
# 63         zone_2 -0.002946
# 65         zone_4 -0.002946
# 47     religion_5 -0.008100
#
# [66 rows x 2 columns]
